# %%
import numpy as np

import noise3d.noise as noise
import noise3d.genseq as genseq

T = V = H = 100

mu = 0
sigma = 1

seq = genseq.genseq_tvh(T, V, H, mu, sigma)

# ces 3 méthodes sont équivalentes en résultats
a = np.array(noise.get_all_3d_classic_var_matrix(seq))
b = np.array(noise.get_all_3d_noise_var_fast(seq))
c = np.array(noise.get_all_3D_noise_var(seq))


d = np.array(noise.get_all_3d_corrected_var_matrix(seq))

# %%
# %timeit noise.get_all_3d_classic_var_matrix(seq)
# %timeit noise.get_all_3D_noise_var(seq)
# %timeit noise.get_all_3d_noise_var_fast(seq)

# %timeit noise.get_all_3d_corrected_var_matrix(seq)
# Out:
# 8.48 ms ± 132 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 46 ms ± 1.66 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 6.39 ms ± 137 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.64 ms ± 79.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
