# %%
import numpy as np

import genseq
import noise

T = V = H = 100

mu = 0
sigma = 1

seq = genseq.genseq_tvh(T, V, H, mu, sigma)

a = np.array(noise.get_all_3d_classic_var_matrix(seq))
b = np.array(noise.get_all_3d_noise_var_fast(seq))
c = np.array(noise.get_all_3D_noise_var(seq))

d = np.array(noise.get_all_3d_corrected_var_matrix(seq))

# %%
print(a[-1])
print(b[-1])
print(c[-1])
print(d[-1])
# Out:
# 0.9992368065256073
# 0.9992368065256074
# 0.9992368065256074
# 0.999236516769614

# %%
for i in range(1,7):
    print(a[0][i])
    print(b[0][i])
    print(c[0][i])
    print(d[0][i])
# Out:
# 0.0001045198324481267
# 0.0001045198324481267
# 0.00010451983244812669
# 8.20794122770276e-07
# 8.556896259165277e-05
# 8.556896259165277e-05
# 8.556896259165277e-05
# -1.859421918080692e-05
# 0.009906127504973217
# 0.009906127504973218
# 0.009906127504973218
# 0.00012096814996255698
# 0.009951810386123501
# 0.009951810386123505
# 0.009951810386123503
# 0.00016738249467288142
# 0.010044104393858376
# 0.010044104393858375
# 0.010044104393858376
# 0.0002617270439430573
# 0.9690585712096894
# 0.9690585712096895
# 0.9690585712096895
# 0.9987208638630032
