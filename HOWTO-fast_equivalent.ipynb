# %%
import numpy as np

import noise3d.genseq as genseq
import noise3d.noise as noise

T = V = H = 100

mu = 0
sigma = 1

seq = genseq.genseq_tvh(T, V, H, mu, sigma)

a = np.array(noise.get_all_3d_classic_var_matrix(seq))
b = np.array(noise.get_all_3d_noise_var_fast(seq))
c = np.array(noise.get_all_3D_noise_var(seq))
d = np.array(noise.get_all_3d_corrected_var_matrix(seq))

# %%
print(a[-1])
print(b[-1])
print(c[-1])
print(d[-1])
# Out:
# 0.9994596076502437
# 0.9994596076502436
# 0.9994596076502436
# 0.9994599043005392

# %%
for i in range(1,7):
    print(a[i])
    print(b[i])
    print(c[i])
    print(d[i])
# Out:
# 9.557528561385614e-05
# 9.557528561385613e-05
# 9.557528561385613e-05
# -5.429531103691927e-06
# 0.0001265245267975877
# 0.0001265245267975877
# 0.0001265245267975877
# 2.7516121992685646e-05
# 0.010022970233301188
# 0.010024993699207898
# 0.010024993699207898
# 0.00023462812351259524
# 0.009826975904822188
# 0.009829305798859425
# 0.009829305798859427
# 3.498693224799655e-05
# 0.009668291103599682
# 0.009670490111643358
# 0.009670490111643358
# -0.0001270371526896092
# 0.9696104758251454
# 0.9696039234571576
# 0.9696101550324998
# 0.9992890700931824
