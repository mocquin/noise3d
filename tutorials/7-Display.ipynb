# %%
import sys
sys.path.append("/Users/mocquin/MYLIB10/MODULES/noise3D/")

# %%
import matplotlib.pyplot as plt
import numpy as np


import noise3d

# %%
T = V = H = 10
seq = noise3d.genseq.genseq_tvh(T, V, H, 0, 1)

# %% [markdown]
# # Single histogram

# %%
noise3d.disp.histo_seq(seq, nbin=100)

# %% [markdown]
# # Noise Histograms

# %%
fig = noise3d.disp.display_8seq(seq,
                                extract=True, # use extract=True to fast-compute the sequences
                                figsize=(14, 8), 
                                samex=True) # use samex for better visual scale between the plots

# %% [markdown]
# # String version

# %%
print(noise3d.disp.noise_resume(seq))
# Out:
# -------------------------------------------------
# Mean : -0.015 | Var : 1.046 | Sum : -14.681
# T : 10 | V : 10 |  H : 10 | Max error : -30.0%
# ---------------- fast       ---------------------
# $\sigma^2_tot$ :  1.047 | $\sigma^2_v$ :   0.004 | $\sigma^2_h$ :   0.012 | $\sigma^2_vh$ :   0.082
# $\sigma^2_t$ :    0.014 | $\sigma^2_tv$ :  0.079 | $\sigma^2_th$ :  0.090 | $\sigma^2_tvh$ :  0.767
# -------------------------------------------------

# %% [markdown]
# # Display noise spectrums

# %%
fig = noise3d.disp.disp_spectrum(seq, figsize=(12, 6),
                                 xt=0, xv=0, xh=0)

# %% [markdown]
# # Display noise sequences

# %%
T = V = H = 100

volumes = noise3d.genseq.genseq_all_seq(T, V, H, (1 for i in range(7)), names=True)
names = volumes[-1]
volumes  = volumes[:-1]
print(names)
# Out:
# ('t', 'v', 'h', 'tv', 'th', 'vh', 'tvh', 'tot')

# %%
# %matplotlib widget 
# prefer '%matplotlib qt' for better performance
viewer = noise3d.disp.SequenceViewer(volumes)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
