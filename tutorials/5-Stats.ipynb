# %%
import sys
sys.path.append("/Users/mocquin/MYLIB10/MODULES/noise3d/")

# %%
import noise3d
import noise3d.stats

# %%
T = V = H = 100
seq = noise3d.genseq.genseq_tvh(T, V, H, 0, 1)

# %% [markdown]
# # Basic statistics

# %%
noise3d.stats.basic_stats(seq)
# Out:
# {'min': -4.8004434776222284,
#  'max': 4.59483514692161,
#  'median': 0.0005525822424195664,
#  'mean': 0.0007949762592689112,
#  'var': 0.9990569507863346,
#  'std': 0.9995283641729906,
#  'count': 1000000}

# %% [markdown]
# # Confidence intervals

# %%
# raw normal CI
noise3d.stats.compute_CI(seq, print_CI=True)
# Out:
# \sigma_{X} unknow, estimating it and using Student's t distribution for Xmean
# \mu is within 0.0007949762592689112+-0.001959041966462871 at 0.05%
# \mu_X not known, using chi2 score with df=n-1 to compute CI for var
# Var_x is wihtin 0.9990569507863346+-0.996736236739588/1.001384206784517 at 0.05%
# {'ci_Xbar_m': -0.001959041966462871,
#  'ci_Xbar_p': 0.001959041966462871,
#  'ci_var_m': 0.996736236739588,
#  'ci_var_p': 1.001384206784517}

# %%
# Improve CI if mean and std are known
noise3d.stats.compute_CI(seq, mu_X=0, sigma_X=1, print_CI=True)
# Out:
# \sigma_X known, using z-score to compute CI for Xmean
# \mu is within 0.0007949762592689112+/-0.001959963984540054 at 0.05%
# \mu_X known, using chi2 score with df=n to compute CI for var
# Var_x is wihtin 0.9990575827742197+-0.9967368672594257/1.001384840244588 at 0.05%
# {'ci_Xbar_m': -0.001959963984540054,
#  'ci_Xbar_p': 0.001959963984540054,
#  'ci_var_m': 0.9967368672594257,
#  'ci_var_p': 1.001384840244588}

# %%
# change the alpha parameter : you get smaller CI but with less chance the actual value is in this CI
noise3d.stats.compute_CI(seq, print_CI=True, alpha=0.5)
# Out:
# \sigma_{X} unknow, estimating it and using Student's t distribution for Xmean
# \mu is within 0.0007949762592689112+-0.0006741718818844806 at 0.5%
# \mu_X not known, using chi2 score with df=n-1 to compute CI for var
# Var_x is wihtin 0.9990569507863346+-0.99905661776705/0.99905661776705 at 0.5%
# {'ci_Xbar_m': -0.0006741718818844806,
#  'ci_Xbar_p': 0.0006741718818844806,
#  'ci_var_m': 0.99905661776705,
#  'ci_var_p': 0.99905661776705}

# %%
noise3d.stats.compute_CI(seq, print_CI=True, alpha=0.5, law_X="poisson")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-8-eb02b2ebb2d2> in <module>
# ----> 1 noise3d.stats.compute_CI(seq, print_CI=True, alpha=0.5, law_X="poisson")
#
# ~/MYLIB10/MODULES/noise3d/noise3d/stats.py in compute_CI(data, mu_X, sigma_X, law_X, alpha, print_CI, ddof)
#      39     """
#      40     if not law_X=="normal":
# ---> 41         raise NotImplementedError("data must be gaussian.")
#      42
#      43     d_count = data.size
#
# NotImplementedError: data must be gaussian.

# %% [markdown]
# # Wrapped
